# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split #splitting the dataset
from autogluon.tabular import TabularDataset, TabularPredictor #to handle tabular data and train models
df=pd.read_csv('healthcare-dataset-stroke-data.csv') # path to colab notebook #replace this with the path to your dataset
# df = df.dropna() # drop NaN columns

# %%
# split into train and test sets
df_train,df_test=train_test_split(df,test_size=0.2,random_state=1)
df_train.shape,df_test.shape
# Out:
# ((4088, 12), (1022, 12))

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# We need to drop the outcome column from the newly created test set

# %%
test_data=df_test.drop(['stroke'],axis=1)

test_data.head()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 4673  49833  Female  42.0             0              0          Yes
# 3232  20375  Female  78.0             0              0          Yes
# 3694  39834    Male  28.0             0              0           No
# 1070  42550  Female  81.0             0              0          Yes
# 4163  19907  Female  52.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status
# 4673       Govt_job          Rural             112.98  37.2  formerly smoked
# 3232        Private          Urban              78.29  30.1  formerly smoked
# 3694        Private          Urban              73.27  25.4           smokes
# 1070  Self-employed          Rural             246.34  21.1     never smoked
# 4163        Private          Rural              97.05  28.0          Unknown

# %% [markdown]
# Now, we build a predictor to train for classifying whether an individual with a given set of conditions will probably be at risk of a stroke. For this, we specify the outcome column as ‘stroke’ and ask the predictor to fit the algorithms on the train dataset. Arguments (optional) ‘verbosity=2’ will display all the steps the predictor is taking to arrive at the best model while ‘presets= best quality’ will ensure that the best model is selected from the trained ones.

# %%
predictor= TabularPredictor(label ='stroke',problem_type='regression').fit(train_data = df_train, verbosity = 2,presets='best_quality')

# %% [markdown]
# Though we have not specified but AutoGluon perfectly understands that this is a binary classification problem based on the two unique labels ‘0’ & ‘1’ in the outcome column

# %%
# print a summary of the models it has trained 
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3  -0.193571       2.005770  313.201953                0.000000           0.282416            3       True         22
# 1          CatBoost_BAG_L2  -0.195461       1.182480  221.682738                0.022591          54.628872            2       True         16
# 2      WeightedEnsemble_L2  -0.195483       0.540746  106.942197                0.000000           0.323457            2       True         12
# 3   NeuralNetFastAI_BAG_L2  -0.195564       1.451685  198.660334                0.291796          31.606468            2       True         18
# 4          CatBoost_BAG_L1  -0.196341       0.015623   45.795909                0.015623          45.795909            1       True          6
# 5        LightGBMXT_BAG_L2  -0.196654       1.299813  183.612579                0.139924          16.558713            2       True         13
# 6        LightGBMXT_BAG_L1  -0.197135       0.050904   12.486674                0.050904          12.486674            1       True          3
# 7          LightGBM_BAG_L2  -0.198325       1.191129  183.472270                0.031240          16.418404            2       True         14
# 8     ExtraTreesMSE_BAG_L2  -0.198692       1.362969  167.922849                0.203080           0.868983            2       True         17
# 9     LightGBMLarge_BAG_L2  -0.198988       1.237965  187.749068                0.078076          20.695202            2       True         21
# 10         LightGBM_BAG_L1  -0.199409       0.072534   13.968441                0.072534          13.968441            1       True          4
# 11    LightGBMLarge_BAG_L1  -0.199728       0.102933   16.090796                0.102933          16.090796            1       True         11
# 12  NeuralNetFastAI_BAG_L1  -0.200992       0.215078   31.650030                0.215078          31.650030            1       True          8
# 13          XGBoost_BAG_L2  -0.201665       1.270303  188.561298                0.110414          21.507432            2       True         19
# 14    ExtraTreesMSE_BAG_L1  -0.202745       0.156208    0.595331                0.156208           0.595331            1       True          7
# 15  RandomForestMSE_BAG_L2  -0.203346       1.322793  171.094590                0.162905           4.040724            2       True         15
# 16          XGBoost_BAG_L1  -0.204584       0.109351   13.876222                0.109351          13.876222            1       True          9
# 17  RandomForestMSE_BAG_L1  -0.204894       0.201344    1.318303                0.201344           1.318303            1       True          5
# 18   NeuralNetTorch_BAG_L1  -0.214391       0.203078   31.263182                0.203078          31.263182            1       True         10
# 19   NeuralNetTorch_BAG_L2  -0.214682       1.472332  205.292623                0.312443          38.238757            2       True         20
# 20   KNeighborsUnif_BAG_L1  -0.224611       0.027792    0.000000                0.027792           0.000000            1       True          1
# 21   KNeighborsDist_BAG_L1  -0.225843       0.005044    0.008978                0.005044           0.008978            1       True          2
# Number of models trained: 22
# Types of models trained:
# {'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_TabularNeuralNetTorch', 'WeightedEnsembleModel', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XT'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 2 | ['work_type', 'smoking_status']
# ('float', [])     : 3 | ['age', 'avg_glucose_level', 'bmi']
# ('int', [])       : 1 | ['id']
# ('int', ['bool']) : 5 | ['gender', 'hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# Plot summary of models saved to file: AutogluonModels/ag-20220627_175113\SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': -0.2246109927094904,
#   'KNeighborsDist_BAG_L1': -0.22584325452813103,
#   'LightGBMXT_BAG_L1': -0.19713542356626704,
#   'LightGBM_BAG_L1': -0.19940874132650865,
#   'RandomForestMSE_BAG_L1': -0.20489391124221842,
#   'CatBoost_BAG_L1': -0.19634111309259894,
#   'ExtraTreesMSE_BAG_L1': -0.20274504298295737,
#   'NeuralNetFastAI_BAG_L1': -0.2009924216302195,
#   'XGBoost_BAG_L1': -0.20458440024806243,
#   'NeuralNetTorch_BAG_L1': -0.2143912622723148,
#   'LightGBMLarge_BAG_L1': -0.19972812812405327,
#   'WeightedEnsemble_L2': -0.19548336575098316,
#   'LightGBMXT_BAG_L2': -0.1966541806897543,
#   'LightGBM_BAG_L2': -0.19832457726111685,
#   'RandomForestMSE_BAG_L2': -0.20334623413307124,
#   'CatBoost_BAG_L2': -0.19546108513876975,
#   'ExtraTreesMSE_BAG_L2': -0.19869213366917662,
#   'NeuralNetFastAI_BAG_L2': -0.1955635828678208,
#   'XGBoost_BAG_L2': -0.20166494651316413,
#   'NeuralNetTorch_BAG_L2': -0.21468161942329414,
#   'LightGBMLarge_BAG_L2': -0.19898841653645996,
#   'WeightedEnsemble_L3': -0.19357125779590084},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': 'AutogluonModels/ag-20220627_175113\\models\\KNeighborsUnif_BAG_L1\\',
#   'KNeighborsDist_BAG_L1': 'AutogluonModels/ag-20220627_175113\\models\\KNeighborsDist_BAG_L1\\',
#   'LightGBMXT_BAG_L1': 'AutogluonModels/ag-20220627_175113\\models\\LightGBMXT_BAG_L1\\',
#   'LightGBM_BAG_L1': 'AutogluonModels/ag-20220627_175113\\models\\LightGBM_BAG_L1\\',
#   'RandomForestMSE_BAG_L1': 'AutogluonModels/ag-20220627_175113\\models\\RandomForestMSE_BAG_L1\\',
#   'CatBoost_BAG_L1': 'AutogluonModels/ag-20220627_175113\\models\\CatBoost_BAG_L1\\',
#   'ExtraTreesMSE_BAG_L1': 'AutogluonModels/ag-20220627_175113\\models\\ExtraTreesMSE_BAG_L1\\',
#   'NeuralNetFastAI_BAG_L1': 'AutogluonModels/ag-20220627_175113\\models\\NeuralNetFastAI_BAG_L1\\',
#   'XGBoost_BAG_L1': 'AutogluonModels/ag-20220627_175113\\models\\XGBoost_BAG_L1\\',
#   'NeuralNetTorch_BAG_L1': 'AutogluonModels/ag-20220627_175113\\models\\NeuralNetTorch_BAG_L1\\',
#   'LightGBMLarge_BAG_L1': 'AutogluonModels/ag-20220627_175113\\models\\LightGBMLarge_BAG_L1\\',
#   'WeightedEnsemble_L2': 'AutogluonModels/ag-20220627_175113\\models\\WeightedEnsemble_L2\\',
#   'LightGBMXT_BAG_L2': 'AutogluonModels/ag-20220627_175113\\models\\LightGBMXT_BAG_L2\\',
#   'LightGBM_BAG_L2': 'AutogluonModels/ag-20220627_175113\\models\\LightGBM_BAG_L2\\',
#   'RandomForestMSE_BAG_L2': 'AutogluonModels/ag-20220627_175113\\models\\RandomForestMSE_BAG_L2\\',
#   'CatBoost_BAG_L2': 'AutogluonModels/ag-20220627_175113\\models\\CatBoost_BAG_L2\\',
#   'ExtraTreesMSE_BAG_L2': 'AutogluonModels/ag-20220627_175113\\models\\ExtraTreesMSE_BAG_L2\\',
#   'NeuralNetFastAI_BAG_L2': 'AutogluonModels/ag-20220627_175113\\models\\NeuralNetFastAI_BAG_L2\\',
#   'XGBoost_BAG_L2': 'AutogluonModels/ag-20220627_175113\\models\\XGBoost_BAG_L2\\',
#   'NeuralNetTorch_BAG_L2': 'AutogluonModels/ag-20220627_175113\\models\\NeuralNetTorch_BAG_L2\\',
#   'LightGBMLarge_BAG_L2': 'AutogluonModels/ag-20220627_175113\\models\\LightGBMLarge_BAG_L2\\',
#   'WeightedEnsemble_L3': 'AutogluonModels/ag-20220627_175113\\models\\WeightedEnsemble_L3\\'},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.0,
#   'KNeighborsDist_BAG_L1': 0.00897836685180664,
#   'LightGBMXT_BAG_L1': 12.486673593521118,
#   'LightGBM_BAG_L1': 13.968440532684326,
#   'RandomForestMSE_BAG_L1': 1.318303108215332,
#   'CatBoost_BAG_L1': 45.79590940475464,
#   'ExtraTreesMSE_BAG_L1': 0.5953309535980225,
#   'NeuralNetFastAI_BAG_L1': 31.6500301361084,
#   'XGBoost_BAG_L1': 13.876221656799316,
#   'NeuralNetTorch_BAG_L1': 31.263181924819946,
#   'LightGBMLarge_BAG_L1': 16.09079623222351,
#   'WeightedEnsemble_L2': 0.3234567642211914,
#   'LightGBMXT_BAG_L2': 16.55871295928955,
#   'LightGBM_BAG_L2': 16.41840410232544,
#   'RandomForestMSE_BAG_L2': 4.040724039077759,
#   'CatBoost_BAG_L2': 54.62887239456177,
#   'ExtraTreesMSE_BAG_L2': 0.8689827919006348,
#   'NeuralNetFastAI_BAG_L2': 31.606468439102173,
#   'XGBoost_BAG_L2': 21.507431983947754,
#   'NeuralNetTorch_BAG_L2': 38.23875713348389,
#   'LightGBMLarge_BAG_L2': 20.695202350616455,
#   'WeightedEnsemble_L3': 0.28241586685180664},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.027791976928710938,
#   'KNeighborsDist_BAG_L1': 0.005043983459472656,
#   'LightGBMXT_BAG_L1': 0.050904273986816406,
#   'LightGBM_BAG_L1': 0.07253384590148926,
#   'RandomForestMSE_BAG_L1': 0.20134449005126953,
#   'CatBoost_BAG_L1': 0.015622615814208984,
#   'ExtraTreesMSE_BAG_L1': 0.15620779991149902,
#   'NeuralNetFastAI_BAG_L1': 0.21507811546325684,
#   'XGBoost_BAG_L1': 0.10935068130493164,
#   'NeuralNetTorch_BAG_L1': 0.2030782699584961,
#   'LightGBMLarge_BAG_L1': 0.10293292999267578,
#   'WeightedEnsemble_L2': 0.0,
#   'LightGBMXT_BAG_L2': 0.1399238109588623,
#   'LightGBM_BAG_L2': 0.031240224838256836,
#   'RandomForestMSE_BAG_L2': 0.1629045009613037,
#   'CatBoost_BAG_L2': 0.022591114044189453,
#   'ExtraTreesMSE_BAG_L2': 0.2030799388885498,
#   'NeuralNetFastAI_BAG_L2': 0.2917964458465576,
#   'XGBoost_BAG_L2': 0.1104135513305664,
#   'NeuralNetTorch_BAG_L2': 0.3124430179595947,
#   'LightGBMLarge_BAG_L2': 0.07807612419128418,
#   'WeightedEnsemble_L3': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                      model  score_val  pred_time_val    fit_time  \
#  0      WeightedEnsemble_L3  -0.193571       2.005770  313.201953
#  1          CatBoost_BAG_L2  -0.195461       1.182480  221.682738
#  2      WeightedEnsemble_L2  -0.195483       0.540746  106.942197
#  3   NeuralNetFastAI_BAG_L2  -0.195564       1.451685  198.660334
#  4          CatBoost_BAG_L1  -0.196341       0.015623   45.795909
#  5        LightGBMXT_BAG_L2  -0.196654       1.299813  183.612579
#  6        LightGBMXT_BAG_L1  -0.197135       0.050904   12.486674
#  7          LightGBM_BAG_L2  -0.198325       1.191129  183.472270
#  8     ExtraTreesMSE_BAG_L2  -0.198692       1.362969  167.922849
#  9     LightGBMLarge_BAG_L2  -0.198988       1.237965  187.749068
#  10         LightGBM_BAG_L1  -0.199409       0.072534   13.968441
#  11    LightGBMLarge_BAG_L1  -0.199728       0.102933   16.090796
#  12  NeuralNetFastAI_BAG_L1  -0.200992       0.215078   31.650030
#  13          XGBoost_BAG_L2  -0.201665       1.270303  188.561298
#  14    ExtraTreesMSE_BAG_L1  -0.202745       0.156208    0.595331
#  15  RandomForestMSE_BAG_L2  -0.203346       1.322793  171.094590
#  16          XGBoost_BAG_L1  -0.204584       0.109351   13.876222
#  17  RandomForestMSE_BAG_L1  -0.204894       0.201344    1.318303
#  18   NeuralNetTorch_BAG_L1  -0.214391       0.203078   31.263182
#  19   NeuralNetTorch_BAG_L2  -0.214682       1.472332  205.292623
#  20   KNeighborsUnif_BAG_L1  -0.224611       0.027792    0.000000
#  21   KNeighborsDist_BAG_L1  -0.225843       0.005044    0.008978
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.000000           0.282416            3       True
#  1                 0.022591          54.628872            2       True
#  2                 0.000000           0.323457            2       True
#  3                 0.291796          31.606468            2       True
#  4                 0.015623          45.795909            1       True
#  5                 0.139924          16.558713            2       True
#  6                 0.050904          12.486674            1       True
#  7                 0.031240          16.418404            2       True
#  8                 0.203080           0.868983            2       True
#  9                 0.078076          20.695202            2       True
#  10                0.072534          13.968441            1       True
#  11                0.102933          16.090796            1       True
#  12                0.215078          31.650030            1       True
#  13                0.110414          21.507432            2       True
#  14                0.156208           0.595331            1       True
#  15                0.162905           4.040724            2       True
#  16                0.109351          13.876222            1       True
#  17                0.201344           1.318303            1       True
#  18                0.203078          31.263182            1       True
#  19                0.312443          38.238757            2       True
#  20                0.027792           0.000000            1       True
#  21                0.005044           0.008978            1       True
#
#      fit_order
#  0          22
#  1          16
#  2          12
#  3          18
#  4           6
#  5          13
#  6           3
#  7          14
#  8          17
#  9          21
#  10          4
#  11         11
#  12          8
#  13         19
#  14          7
#  15         15
#  16          9
#  17          5
#  18         10
#  19         20
#  20          1
#  21          2  }

# %% [markdown]
# AutoGluon trained 24 models but we would be more interested to find out which is the best model as selected by AutoGluon. To display this, simply use the leaderboard() command which ranks the trained models in order. Use the leaderboard() command which ranks the trained models in order.

# %%
predictor.leaderboard(df_train, silent=True)
# Out:
#                       model  score_test  score_val  pred_time_test  \
# 0     KNeighborsDist_BAG_L1    1.000000   0.954393        0.020875
# 1   RandomForestGini_BAG_L1    1.000000   0.956826        0.140593
# 2   RandomForestEntr_BAG_L1    1.000000   0.956826        0.140593
# 3     ExtraTreesGini_BAG_L1    1.000000   0.956826        0.164960
# 4     ExtraTreesEntr_BAG_L1    1.000000   0.957434        0.166432
# 5            XGBoost_BAG_L1    0.961690   0.956522        0.234319
# 6       WeightedEnsemble_L2    0.958650   0.958954        0.588205
# 7    NeuralNetFastAI_BAG_L1    0.958650   0.958954        0.588205
# 8     ExtraTreesEntr_BAG_L2    0.958346   0.957130        2.687465
# 9     KNeighborsUnif_BAG_L1    0.958042   0.956826        0.013996
# 10  RandomForestGini_BAG_L2    0.958042   0.957130        2.643280
# 11  RandomForestEntr_BAG_L2    0.958042   0.957738        2.643284
# 12    ExtraTreesGini_BAG_L2    0.958042   0.957434        2.686170
# 13          CatBoost_BAG_L1    0.957434   0.956522        0.068105
# 14          LightGBM_BAG_L1    0.957434   0.957738        0.113548
# 15     LightGBMLarge_BAG_L1    0.957434   0.957738        0.115754
# 16        LightGBMXT_BAG_L1    0.957434   0.958650        0.217365
# 17    NeuralNetTorch_BAG_L1    0.957434   0.957434        0.533567
# 18          CatBoost_BAG_L2    0.957434   0.956522        2.596418
# 19          LightGBM_BAG_L2    0.957434   0.958650        2.654564
# 20     LightGBMLarge_BAG_L2    0.957434   0.958042        2.656601
# 21      WeightedEnsemble_L3    0.957434   0.959258        2.794583
# 22        LightGBMXT_BAG_L2    0.957434   0.959258        2.794583
# 23    NeuralNetTorch_BAG_L2    0.957434   0.957434        3.221269
# 24           XGBoost_BAG_L2    0.954697   0.958650        2.815118
# 25   NeuralNetFastAI_BAG_L2    0.954697   0.958954        3.208246
#
#     pred_time_val    fit_time  pred_time_test_marginal  \
# 0        0.021773    0.000000                 0.020875
# 1        0.175899    0.751221                 0.140593
# 2        0.171835    0.729398                 0.140593
# 3        0.187457    0.567576                 0.164960
# 4        0.171840    0.613594                 0.166432
# 5        0.124995   10.493594                 0.234319
# 6        0.218714   32.022558                 0.000000
# 7        0.218714   30.111507                 0.588205
# 8        1.784087  138.106078                 0.169153
# 9        0.019769    0.000000                 0.013996
# 10       1.768455  138.231052                 0.124968
# 11       1.784077  138.324768                 0.124972
# 12       1.987154  138.356088                 0.167858
# 13       0.078092   30.696726                 0.068105
# 14       0.051328   12.799546                 0.113548
# 15       0.062486   12.999369                 0.115754
# 16       0.062485   11.839726                 0.217365
# 17       0.249946   25.873876                 0.533567
# 18       1.643499  181.930346                 0.078107
# 19       1.674722  151.834634                 0.136252
# 20       1.643462  155.509514                 0.138289
# 21       1.721579  153.363983                 0.000000
# 22       1.721579  152.093325                 0.276271
# 23       1.893432  161.918581                 0.702957
# 24       1.705959  149.035941                 0.296806
# 25       1.877853  168.088040                 0.689934
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.021773           0.000000            1       True
# 1                 0.175899           0.751221            1       True
# 2                 0.171835           0.729398            1       True
# 3                 0.187457           0.567576            1       True
# 4                 0.171840           0.613594            1       True
# 5                 0.124995          10.493594            1       True
# 6                 0.000000           1.911051            2       True
# 7                 0.218714          30.111507            1       True
# 8                 0.187468           0.629945            2       True
# 9                 0.019769           0.000000            1       True
# 10                0.171835           0.754919            2       True
# 11                0.187457           0.848634            2       True
# 12                0.390534           0.879955            2       True
# 13                0.078092          30.696726            1       True
# 14                0.051328          12.799546            1       True
# 15                0.062486          12.999369            1       True
# 16                0.062485          11.839726            1       True
# 17                0.249946          25.873876            1       True
# 18                0.046880          44.454212            2       True
# 19                0.078102          14.358501            2       True
# 20                0.046843          18.033380            2       True
# 21                0.000000           1.270658            3       True
# 22                0.124959          14.617192            2       True
# 23                0.296812          24.442448            2       True
# 24                0.109339          11.559808            2       True
# 25                0.281233          30.611907            2       True
#
#     fit_order
# 0           2
# 1           5
# 2           6
# 3           8
# 4           9
# 5          11
# 6          14
# 7          10
# 8          21
# 9           1
# 10         17
# 11         18
# 12         20
# 13          7
# 14          4
# 15         13
# 16          3
# 17         12
# 18         19
# 19         16
# 20         25
# 21         26
# 22         15
# 23         24
# 24         23
# 25         22

# %% [markdown]
# Additionally, we can also check for the feature importance using

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 11 features using 3289 rows with 5 shuffle sets...
# 	137.53s	= Expected runtime (27.51s per shuffle set)
# 	78.02s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                    importance  stddev  p_value  n  p99_high  p99_low
# id                        0.0     0.0      0.5  5       0.0      0.0
# gender                    0.0     0.0      0.5  5       0.0      0.0
# age                       0.0     0.0      0.5  5       0.0      0.0
# hypertension              0.0     0.0      0.5  5       0.0      0.0
# heart_disease             0.0     0.0      0.5  5       0.0      0.0
# ever_married              0.0     0.0      0.5  5       0.0      0.0
# work_type                 0.0     0.0      0.5  5       0.0      0.0
# Residence_type            0.0     0.0      0.5  5       0.0      0.0
# avg_glucose_level         0.0     0.0      0.5  5       0.0      0.0
# bmi                       0.0     0.0      0.5  5       0.0      0.0
# smoking_status            0.0     0.0      0.5  5       0.0      0.0

# %% [markdown]
# ### Note:
# Here we can see that it has identified age and bmi to be the most important factors in the prediction of the outcome.

# %% [markdown]
# ### Next, we feed the test data to the classifier for prediction and we can store it in a DataFrame

# %%
y_pred = predictor.predict(test_data)
y_pred=pd.DataFrame(y_pred,columns=['stroke'])
y_pred #print the DataFrame
# Out:
#       stroke
# 2648       0
# 3441       0
# 4935       0
# 1316       0
# 3271       0
# ...      ...
# 1026       0
# 2436       0
# 4458       0
# 1354       0
# 265        0
#
# [1620 rows x 1 columns]

# %% [markdown]
# #### To understand the evaluation metric ‘accuracy’, let us print the details for it

# %%
predictor.evaluate(df_test)

# %% [markdown]
# ## Summary
# Data preprocessing and Feature Engineering were carried out by AutoGluon. The trained model includes cross-validation as well. So, we got the trained classifier at 95% accuracy with just two lines of code (for the classifier to train and predict). Now, that’s impressive! If it were a traditional ML model, we would be spending a long time completing the entire process including EDA, data cleaning as well as coding to set up multiple models. AutoGluon made this quite simple for us.
