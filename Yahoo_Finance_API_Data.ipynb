# %% [markdown]
# # install libraries

# %% [markdown]
# ## Accessing Yahoo Financial Data

# %%
pip install --upgrade pandas-datareader

# %% [markdown]
# ### Compatability with Yahoo API Version
# Yahoo made changes to their API that broke compatibility with previous pandas datareader versions.

# %%
pip install git+https://github.com/raphi6/pandas-datareader.git@ea66d6b981554f9d0262038aef2106dda7138316

# %% [markdown]
# ## Load Yahoo Ticker Data

# %%
import pandas_datareader.data as pdr
from datetime import datetime
import yfinance as yf
yf.pdr_override()
y_symbols = ['SCHAND.NS', 'TATAPOWER.NS', 'ITC.NS']
startdate = datetime(2022,12,1)
enddate = datetime(2022,12,15)
data = pdr.get_data_yahoo(y_symbols, start=startdate, end=enddate)
print(data)
# Out:
# [*********************100%%**********************]  3 of 3 completed
#              Adj Close                                Close              \
#                 ITC.NS   SCHAND.NS TATAPOWER.NS      ITC.NS   SCHAND.NS
# Date
# 2022-12-01  332.231262  193.808853   222.775269  339.549988  195.949997
# 2022-12-02  329.882996  194.451767   223.171570  337.149994  196.600006
# 2022-12-05  329.491608  188.962402   222.131256  336.750000  191.050003
# 2022-12-06  330.029724  194.253937   226.688812  337.299988  196.399994
# 2022-12-07  332.769409  185.302841   223.766037  340.100006  187.350006
# 2022-12-08  331.106049  179.862946   222.973419  338.399994  181.850006
# 2022-12-09  334.041382  174.967010   217.375549  341.399994  176.899994
# 2022-12-12  335.802612  175.412109   215.691238  343.200012  177.350006
# 2022-12-13  338.150879  176.500076   216.830627  345.600006  178.449997
# 2022-12-14  337.955139  177.192429   220.645096  345.399994  179.149994
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2022-12-01 to 2022-12-14
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   (Adj Close, ITC.NS)        10 non-null     float64
#  1   (Adj Close, SCHAND.NS)     10 non-null     float64
#  2   (Adj Close, TATAPOWER.NS)  10 non-null     float64
#  3   (Close, ITC.NS)            10 non-null     float64
#  4   (Close, SCHAND.NS)         10 non-null     float64
#  5   (Close, TATAPOWER.NS)      10 non-null     float64
#  6   (High, ITC.NS)             10 non-null     float64
#  7   (High, SCHAND.NS)          10 non-null     float64
#  8   (High, TATAPOWER.NS)       10 non-null     float64
#  9   (Low, ITC.NS)              10 non-null     float64
#  10  (Low, SCHAND.NS)           10 non-null     float64
#  11  (Low, TATAPOWER.NS)        10 non-null     float64
#  12  (Open, ITC.NS)             10 non-null     float64
# ...
